# %%
import pandas as pd
from textblob import TextBlob
from textblob import Word
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import geopandas as gpd
import urllib
import json
from dateutil.parser import parse
from datetime import datetime
import re
from collections import Counter
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np


from nltk import word_tokenize
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')
from string import punctuation  
from nltk.corpus import stopwords  
from nltk import word_tokenize  
from nltk.data import load  
from string import punctuation  
from sklearn.feature_extraction.text import CountVectorizer       


pd.options.display.max_columns = 120
pd.options.display.max_rows = 120
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/geoffperrin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/geoffperrin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Source: https://www.dataquest.io/blog/naive-bayes-tutorial/ & http://blog.manugarri.com/sentiment-analysis-in-spanish/

# %%
#stopword list to use
spanish_stopwords = stopwords.words('spanish')
#punctuation to remove
non_words = list(punctuation)  
#we add spanish punctuation
non_words.extend(['¿', '¡'])  
non_words.extend(map(str,range(10)))

# %%
data = '/Users/geoffperrin/Desktop/bloomberg_work/bogota_project/data/'

# %%
df_w_labels = pd.read_csv(data + 'quejas_English_w_labels.csv', encoding='utf-8')

# %%
df_w_labels = df_w_labels[df_w_labels.complaint_label!='?']
df_w_labels['complaint_binary'] = [1 if i == 'complaint' else 0 for i in df_w_labels['complaint_label']]
df_w_labels.head()
# Out:
#    Unnamed: 0  Numero petición   Sector          Entidad Entidad Nueva  \
# 0           0          2112017  HABITAT  ACUEDUCTO - EAB           NaN
# 1           1          2992017  HABITAT  ACUEDUCTO - EAB           NaN
# 2           2          3622017  HABITAT  ACUEDUCTO - EAB           NaN
# 3           3          3772017  HABITAT  ACUEDUCTO - EAB           NaN
# 4           4          3862017  HABITAT  ACUEDUCTO - EAB           NaN
#
#   Trasladado? Entidad definitiva                            Dependencia  \
# 0         NaN    ACUEDUCTO - EAB  DIRECCION DE SERVICIO ADMINISTRATIVOS
# 1         NaN    ACUEDUCTO - EAB  DIRECCION DE SERVICIO ADMINISTRATIVOS
# 2         NaN    ACUEDUCTO - EAB  DIRECCION DE SERVICIO ADMINISTRATIVOS
# 3         NaN    ACUEDUCTO - EAB  DIRECCION DE SERVICIO ADMINISTRATIVOS
# 4         NaN    ACUEDUCTO - EAB  DIRECCION DE SERVICIO ADMINISTRATIVOS
#
#                  Tema                                            Subtema  \
# 0  SERVICIOS PUBLICOS                ATENCION Y SERVICIO A LA CIUDADANIA
# 1  SERVICIOS PUBLICOS                                   VISITAS TECNICAS
# 2  SERVICIOS PUBLICOS                         DISPONIBILIDAD DE SERVICIO
# 3            AMBIENTE  MANTENIMIENTO DE SUMIDEROS, REJILLAS DE ALCANT...
# 4  SERVICIOS PUBLICOS  RECUPERACIÓN DE ESPACIO PUBLICO POR OBRAS DE L...
#
#   Localidad de los hechos UPZ  de los hechos Barrio de los hecho  \
# 0       4 - SAN CRISTOBAL      32 - SAN BLAS      BELLAVISTA SUR
# 1     12 - BARRIOS UNIDOS     21 - LOS ANDES           ENTRERIOS
# 2           2 - CHAPINERO     99 - CHAPINERO     CHAPINERO NORTE
# 3           2 - CHAPINERO    97 - CHICO LAGO     ANTIGUO COUNTRY
# 4             1 - USAQUEN       14 - USAQUEN             USAQUEN
#
#    Estrato de los hechos Punto atención Canal  \
# 0                    2.0            NaN   WEB
# 1                    4.0            NaN   WEB
# 2                    5.0            NaN   WEB
# 3                    5.0            NaN   WEB
# 4                    6.0            NaN   WEB
#
#                                Tipo petición  \
# 0  DERECHO DE PETICIÓN DE INTERÉS PARTICULAR
# 1                                    RECLAMO
# 2  DERECHO DE PETICIÓN DE INTERÉS PARTICULAR
# 3                                    RECLAMO
# 4                                      QUEJA
#
#                                               Asunto            Fecha ingreso  \
# 0  BUENAS TARDES ES PARA SOLICITAR LA REPARACION ...  2017-01-02 00:00:00.000
# 1  INSTALACION DE MEDIDOR EL 8 DE NOVIEMBRE DE 20...  2017-01-02 00:00:00.000
# 2  EMPRESA DE ACUEDUCTO Y ALCANTARILLADO DE BOGOT...  2017-01-02 00:00:00.000
# 3  FAVOR REPONER LA REJILLA DE SUMNIDERO QUE SE E...  2017-01-02 00:00:00.000
# 4  ME REFIERO A SU COMUNICACION S-2016-245954 LA ...  2017-01-02 00:00:00.000
#
#                                    estado          inicio terminos  \
# 0  SOLUCIONADO - POR RESPUESTA DEFINITIVA  2017-01-03 00:00:00.000
# 1  SOLUCIONADO - POR RESPUESTA DEFINITIVA  2017-01-03 00:00:00.000
# 2  SOLUCIONADO - POR RESPUESTA DEFINITIVA  2017-01-03 00:00:00.000
# 3  SOLUCIONADO - POR RESPUESTA DEFINITIVA  2017-01-03 00:00:00.000
# 4  SOLUCIONADO - POR RESPUESTA DEFINITIVA  2017-01-03 00:00:00.000
#
#                     cierre dias gestión           Fecha registro  \
# 0  2017-01-23 12:59:50.415           14  2017-01-03 00:00:00.000
# 1  2017-01-24 14:26:01.929           15  2017-01-03 00:00:00.000
# 2  2017-02-02 11:20:55.660           22  2017-01-03 00:00:00.000
# 3  2017-02-02 11:55:16.434           22  2017-01-03 00:00:00.000
# 4  2017-01-16 10:47:02.935            9  2017-01-03 00:00:00.000
#
#               Nombre peticionario Condición del peticionario  \
# 0  JERSON  ANDRES ROJAS RODRIGUEZ                        NaN
# 1    AMANDA  OLIVA BOTERO SANCHEZ               ADULTO MAYOR
# 2           JAIME  MONCAYO ARENAS               ADULTO MAYOR
# 3          SERGIO  VALDES BELTRAN                        NaN
# 4          SERGIO  VALDES BELTRAN                        NaN
#
#   Localidad  del ciudadano UPZ del ciudadano Barrio del ciudadano  \
# 0        4 - SAN CRISTOBAL     32 - SAN BLAS       BELLAVISTA SUR
# 1      12 - BARRIOS UNIDOS    21 - LOS ANDES            ENTRERIOS
# 2            2 - CHAPINERO    99 - CHAPINERO      CHAPINERO NORTE
# 3                      NaN               NaN                  NaN
# 4                      NaN               NaN                  NaN
#
#   Estrato del ciudadano Tipo de Peticionario Opciones de Petición  \
# 0                     2              Natural     En nombre propio
# 1                     4              Natural     En nombre propio
# 2                     5              Natural     En nombre propio
# 3                     5              Natural     En nombre propio
# 4                     5              Natural     En nombre propio
#
#   Entidad que recibe Entidad que traslada  \
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
#
#                                            Asunto_EN complaint_label  \
# 0  GOOD AFTERNOON IS TO REQUEST THE REPAIR OF THE...       complaint
# 1  INSTALLATION OF METER ON NOVEMBER 8, 2016, THE...       complaint
# 2  COMPANY OF AQUEDUCT AND SEWER OF BOGOTA, ESP\n...       complaint
# 3  PLEASE REPLACE THE GRILLE OF ABSNIDERO THAT IS...       complaint
# 4  I REFER TO YOUR COMMUNICATION S-2016-245954 WH...       complaint
#
#    complaint_binary
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
df_w_labels.groupby(['Tema', 'complaint_binary'], as_index=False)['Sector'].count()
# Out:
#                                         Tema  complaint_binary  Sector
# 0              1 TRASLADO POR NO COMPETENCIA                 0      16
# 1              1 TRASLADO POR NO COMPETENCIA                 1     103
# 2                                   AMBIENTE                 0      13
# 3                                   AMBIENTE                 1      65
# 4               ARTE - CULTURA - PATRIMONIO                  0      47
# 5  CIENCIA - TECNOLOGIA - COMUNICACIONES TIC                 0      77
# 6  CIENCIA - TECNOLOGIA - COMUNICACIONES TIC                 1       4
# 7                         SERVICIOS PUBLICOS                 0      52
# 8                         SERVICIOS PUBLICOS                 1     608

# %%
df_w_labels.groupby(['complaint_binary'], as_index=False)['Sector'].count()
# Out:
#    complaint_binary  Sector
# 0                 0     207
# 1                 1     788

# %%
def stem_tokens(tokens, stemmer):  
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

# %%
def tokenize(text):  
    # remove punctuation
    text = ''.join([c for c in text if c not in non_words])
    # tokenize
    tokens =  word_tokenize(text)

    # stem
    try:
        stems = stem_tokens(tokens, stemmer)
    except Exception as e:
        print(e)
        print(text)
        stems = ['']
    return stems

# %%
vectorizer = CountVectorizer(  
                analyzer = 'word',
                tokenizer = tokenize,
                lowercase = True,
                stop_words = spanish_stopwords)

# %%
X = df_w_labels['Asunto']
y = df_w_labels['complaint_binary']

# %%
# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
train_features = vectorizer.fit_transform([r for r in X_train])
test_features = vectorizer.transform([r for r in X_test])
# Out:
# /Users/geoffperrin/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   app.launch_new_instance()

# %%
train_features
# Out:
# <696x4732 sparse matrix of type '<type 'numpy.int64'>'
# 	with 29143 stored elements in Compressed Sparse Row format>

# %%
# Fit a naive bayes model to the training data.
# This will train the model using the word counts we computer, and the existing classifications in the training set.
nb = MultinomialNB()
nb.fit(train_features, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Now we can use the model to predict classifications for our test features.
predictions = nb.predict(test_features)

# %%
actual = y_test

# Generate the roc curve using scikits-learn.
fpr, tpr, thresholds = metrics.roc_curve(actual, predictions, pos_label=1)

# Measure the area under the curve.  The closer to 1, the "better" the predictions.
print("AUC of the predictions: {0}".format(metrics.auc(fpr, tpr)))
# Out:
# AUC of the predictions: 0.793723849372

# %% [markdown]
# ## Now read in full complaint data

# %%
xl = pd.ExcelFile(data + "SDQS/SDQS 2017-enejun.xlsx")

# %%
df = xl.parse('DB Recibidos')

# %% [markdown]
# ### Apply model built above to full set of complaints

# %%
full_features = vectorizer.transform([r for r in df['Asunto']])
# Out:
# /Users/geoffperrin/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   app.launch_new_instance()

# %%
complaint_pred = nb.predict(full_features)

# %%
complaint_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
df['complaint_pred'] = complaint_pred

# %%
complaints_by_tema = df.groupby(['Tema', 'complaint_pred'], as_index=False)['Sector'].count()

# %%
pivot = complaints_by_tema.pivot(index='Tema',columns='complaint_pred',values='Sector')

# %%
df_complaints_by_tema = pivot.reset_index()
df_complaints_by_tema.columns = ['Tema', 'non_complaint_count', 'complaint_count']

# %%
df_complaints_by_tema['pct_complaint'] = df_complaints_by_tema.complaint_count / \
(df_complaints_by_tema.non_complaint_count + df_complaints_by_tema.complaint_count)

# %%
#replace nans with zeros
df_complaints_by_tema.fillna(0, inplace=True)

# %%
df_complaints_by_tema.sort_values('pct_complaint', ascending=False)
# Out:
#                                                  Tema  non_complaint_count  \
# 29                                         FINANCIERO                 16.0
# 52                           Obras en Espacio público                  1.0
# 64                   SOLICITUD DE VALORACION FORESTAL                  2.0
# 63                                 SERVICIOS PUBLICOS                124.0
# 17                            CENTRO DE COMANDO - C4                  13.0
# 37                                 GESTION DEL RIESGO                  7.0
# 27                                    ESPACIO PUBLICO                 94.0
# 44                  IMPUESTOS, TASAS Y CONTRIBUCIONES                 68.0
# 21              Consulta Proyectos de Infraestructura                  3.0
# 48                MOVILIDAD - TRANSPORTE - MALLA VIAL                659.0
# 65                                          SUBSIDIOS                264.0
# 61          SEGURIDAD LOCAL Y PROBLEMÁTICAS ASOCIADAS                  8.0
# 13                                           AMBIENTE                600.0
# 30                  FUNCION PUBLICA - ADMINISTRACION                1045.0
# 47                                          MIGRACION                 36.0
# 54                              PREVENCION DEL DELITO                  4.0
# 50            ORGANIZACIÓN Y ESTRUCTURA - BOGOTÁ D.C.                  4.0
# 16                                   CARCEL DISTRITAL                160.0
# 0                       1 TRASLADO POR NO COMPETENCIA               1907.0
# 71                             URBANISMO - VIVIENDA                  540.0
# 2                         10. Presunto Evento Adverso                  5.0
# 4          2. Dificultad Accesibilidad Administrativa                112.0
# 20                CONTROL POLITICO -  SOCIAL - FISCAL                152.0
# 1                           1. Atención Deshumanizada                117.0
# 11                      9. No Suministro Medicamentos                 59.0
# 10                        8. No Oportunidad Servicios                284.0
# 3                   11. Problemas Recursos Económicos                 10.0
# 25                                  ECONOMIA INFORMAL                387.0
# 9                               7. Negación Servicios                 24.0
# 8             6. Incumplimiento Portabilidad Nacional                  1.0
# 19         COMERCIO - CONSUMIDORES BIENES Y SERVICIOS                 29.0
# 5                            3. Dificultad Alto Costo                  3.0
# 72                                       VALORIZACION                  2.0
# 42                                     GOBIERNO LOCAL               6477.0
# 57             Reorganización Sector Salud - Subredes                 25.0
# 53                            PARTICIPACION CIUDADANA                130.0
# 28                                            FAMILIA                843.0
# 12                                    ADMINISTRATIVOS                236.0
# 45                               Imagen Institucional                  3.0
# 24       DIVERSIDAD POBLACIONAL Y ENFOQUE DIFERENCIAL                246.0
# 62                            SEGURIDAD Y CONVIVENCIA                764.0
# 59                                              SALUD               4115.0
# 49                                            MUJERES                265.0
# 22                                            DEPORTE                649.0
# 15                                  ASISTENCIA SOCIAL                221.0
# 7   5. Inconsistencias Sistemas de Información-Ase...                 17.0
# 60                                     SECTORES LGBTI                  9.0
# 67                                            TURISMO                 72.0
# 23                                       DISCAPACIDAD                241.0
# 46             Información sobre Trámites y Servicios                  2.0
# 6                               4. Dificultad Tutelas                 17.0
# 66                                            TRABAJO                  9.0
# 31      GERENCIA JURIDICA Y DEFENSA PUBLICA DISTRITAL                 98.0
# 26                                          EDUCACION               7732.0
# 70                        Trámites laborales internos                  2.0
# 14                       ARTE - CULTURA - PATRIMONIO                2307.0
# 33             GESTION ASUNTOS LOCALES Y PATICIPACION                  8.0
# 18          CIENCIA - TECNOLOGIA - COMUNICACIONES TIC                170.0
# 56                  RESPONSABILIDAD PENAL ADOLESCENTE                  1.0
# 58                            Reporte sobre Actuación                  0.0
# 55              Predios para obras de Infraestructura                  0.0
# 34              GESTION DE ARTE, CULTURA Y PATRIMONIO                 15.0
# 51              Obras de infraestructura en ejecución                  0.0
# 43            Huecos Malla Vial Arterial e Intermedia                  0.0
# 41                        GESTION PERSONAS JURIDICAS                   1.0
# 40                      GESTION LECTURA Y BIBLIOTECAS                  4.0
# 39             GESTION JURIDICA -  LEGAL – REGULACION                  2.0
# 38                                    GESTION FOMENTO                 10.0
# 68                        Traslados a otras entidades                  0.0
# 69                  Trámites administrativos externos                  1.0
# 32                             GESTION ADMINISTRATIVA                  4.0
# 35          GESTION DE COMUNICACIONES Y PUBLICACIONES                  4.0
# 36                              GESTION DE PLANEACION                  1.0
#
#     complaint_count  pct_complaint
# 29           1441.0       0.989019
# 52             64.0       0.984615
# 64            103.0       0.980952
# 63           3640.0       0.967056
# 17            256.0       0.951673
# 37            130.0       0.948905
# 27           1501.0       0.941066
# 44           1002.0       0.936449
# 21             40.0       0.930233
# 48           8552.0       0.928455
# 65           3379.0       0.927532
# 61            101.0       0.926606
# 13           7294.0       0.923993
# 30          12492.0       0.922804
# 47            422.0       0.921397
# 54             40.0       0.909091
# 50             38.0       0.904762
# 16           1491.0       0.903089
# 0           14868.0       0.886319
# 71           4033.0       0.881916
# 2              37.0       0.880952
# 4             777.0       0.874016
# 20           1025.0       0.870858
# 1             777.0       0.869128
# 11            362.0       0.859857
# 10           1432.0       0.834499
# 3              50.0       0.833333
# 25           1734.0       0.817539
# 9             106.0       0.815385
# 8               4.0       0.800000
# 19            109.0       0.789855
# 5              11.0       0.785714
# 72              7.0       0.777778
# 42          22073.0       0.773135
# 57             81.0       0.764151
# 53            407.0       0.757914
# 28           2541.0       0.750887
# 12            592.0       0.714976
# 45              7.0       0.700000
# 24            571.0       0.698898
# 62           1624.0       0.680067
# 59           8413.0       0.671536
# 49            524.0       0.664132
# 22           1281.0       0.663731
# 15            430.0       0.660522
# 7              27.0       0.613636
# 60             14.0       0.608696
# 67            110.0       0.604396
# 23            364.0       0.601653
# 46              3.0       0.600000
# 6              22.0       0.564103
# 66              8.0       0.470588
# 31             80.0       0.449438
# 26           3925.0       0.336708
# 70              1.0       0.333333
# 14           1029.0       0.308453
# 33              2.0       0.200000
# 18             31.0       0.154229
# 56              0.0       0.000000
# 58              2.0       0.000000
# 55              7.0       0.000000
# 34              0.0       0.000000
# 51              8.0       0.000000
# 43             51.0       0.000000
# 41              0.0       0.000000
# 40              0.0       0.000000
# 39              0.0       0.000000
# 38              0.0       0.000000
# 68              1.0       0.000000
# 69              0.0       0.000000
# 32              0.0       0.000000
# 35              0.0       0.000000
# 36              0.0       0.000000

# %%
114003.0 / (114003+31977)
# Out:
# 0.7809494451294698
